# %% [markdown]
# # W01 论文写作专题：计量方法选择与汇报规范
#
# > **说明**：本 Notebook 为占位文档，内容将持续补充。
#
# ---
#
# ## 目录
#
# 1. [方法选择决策树](#1-方法选择决策树)
# 2. [假设检验与显著性汇报规范](#2-假设检验与显著性汇报规范)
# 3. [回归表格排版（stargazer / estout 风格）](#3-回归表格排版)
# 4. [稳健性检验清单](#4-稳健性检验清单)
# 5. [因果推断证据强度排序](#5-因果推断证据强度排序)
# 6. [中文顶刊行文结构参考](#6-中文顶刊行文结构参考)

# %% [markdown]
# ## 1. 方法选择决策树
#
# > *(待补充：根据研究问题类型 / 数据结构 / 内生性来源给出方法路径图)*
#
# ```
# 研究目标
# ├── 描述性因果：OLS + 控制变量
# ├── 自然实验
# │   ├── 随机断点  → RDD (T06)
# │   ├── 政策冲击  → DiD / Event Study (T05, T08)
# │   └── 历史工具  → IV/2SLS (T03)
# ├── 选择偏差     → PSM (T07) / 合成控制 (T11)
# ├── 面板固定效应 → FE/RE (T04)
# ├── 离散因变量   → Logit/Probit (T02)
# └── 时间序列
#     ├── 波动率建模 → GARCH (T09)
#     └── 多变量系统 → VAR (T10)
# ```

# %% [markdown]
# ## 2. 假设检验与显著性汇报规范
#
# > *(待补充：APA 格式 vs 经济学期刊惯例、星号注释、系数与标准误/t值并排报告)*
#
# **占位内容**
# - `***` p<0.01，`**` p<0.05，`*` p<0.1（经济学惯例）
# - 括号内汇报标准误（稳健SE优先），而非 t 值
# - 始终报告 R²、样本量、固定效应说明

# %% [markdown]
# ## 3. 回归表格排版
#
# > *(待补充：Python `stargazer` / `pystargaze` 用法，以及 Stata `estout` 对应命令)*

# %%
# 占位：后续将展示 Python 自动生成 LaTeX/HTML 回归表
# 示例依赖：pip install stargazer
print('TODO: 自动回归表生成示例')

# %% [markdown]
# ## 4. 稳健性检验清单
#
# > *(待补充：各方法对应的标准稳健性检验项目)*
#
# | 模型 | 必做稳健性检验 |
# |------|---------------|
# | OLS | 异方差检验(BP/White)、替换控制变量、子样本 |
# | IV  | 弱工具变量(F>10)、过度识别(Sargan)、LIML |
# | DiD | 平行趋势图、安慰剂检验、渐进双重差分 |
# | RDD | 带宽敏感性、密度连续性(McCrary)、协变量平衡 |
# | PSM | 平衡性检验、核匹配 vs 最近邻、ATT vs ATE |
# | SC  | 原位安慰剂、RMSPE比率 |

# %% [markdown]
# ## 5. 因果推断证据强度排序
#
# > *(待补充：证据强度金字塔与各方法在经济学论文中的认可度)*
#
# ```
# 强  ▲  RCT（随机对照实验）
#     │  自然实验（外生冲击：DiD/RDD/IV）
#     │  合成控制法
#     │  PSM + 双重差分
# 弱  ▼  OLS + 控制变量
# ```

# %% [markdown]
# ## 6. 中文顶刊行文结构参考
#
# > *(待补充：《经济研究》《管理世界》《经济学(季刊)》典型论文结构分析)*
#
# **标准结构（约8000-15000字）**
#
# 1. 引言（问题 → 贡献 → 结构）
# 2. 文献综述（国内外研究 → 本文边际贡献）
# 3. 理论机制（模型 / 假说推导）
# 4. 研究设计（数据 + 计量模型 + 识别策略）
# 5. 实证结果（基准回归 → 机制检验）
# 6. 稳健性检验
# 7. 结论与政策含义
