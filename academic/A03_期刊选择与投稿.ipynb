# %% [markdown]
# # A03 期刊选择与投稿指南
#
# 投稿是论文发表的最后一关，也是最容易因为信息不对称而踩坑的地方。
# 本篇帮你建立清晰的期刊认知体系，掌握从选刊到回复审稿意见的完整流程。
#
# ---

# %% [markdown]
# ## 一、期刊体系：你需要知道的分类逻辑
#
# ### 国际期刊
#
# 学界最广泛认可的国际分类体系是**科睿唯安（Clarivate）**维护的引文数据库：
#
# | 名称 | 全称 | 适用学科 |
# |------|------|---------|
# | **SCI** | Science Citation Index | 自然科学、工程、医学 |
# | **SSCI** | Social Sciences Citation Index | 经济、管理、社会、心理 |
# | **A&HCI** | Arts & Humanities Citation Index | 人文艺术 |
# | **EI** | Engineering Index | 工程类 |
# | **ESCI** | Emerging Sources Citation Index | SCI/SSCI 候选，认可度偏低 |
#
# **SCI/SSCI 的分区（以中科院分区为标准，国内最通用）：**
#
# ```
# Q1（一区）：期刊 IF 在该学科前 25%    ← 多数学校认定为"高水平"
# Q2（二区）：25% ~ 50%               ← 各学校认可，对毕业要求友好
# Q3（三区）：50% ~ 75%               ← 审稿宽松，见刊快，保底选项
# Q4（四区）：75% ~ 100%              ← 部分已接近"水刊"
# ```
#
# > 中科院分区每年 12 月更新，查询地址：[中科院文献情报中心分区表](https://www.fenqubiao.com)
#
# ### 国内期刊
#
# | 名称 | 维护机构 | 更新周期 | 主要学科 |
# |------|---------|---------|---------|
# | **CSSCI**（南大核心） | 南京大学 | 两年 | 社科类权威 |
# | **北大核心** | 北京大学图书馆 | 四年 | 综合 |
# | **CSCD** | 中国科学院 | 两年 | 理工科为主 |
#
# > 国内评职称/毕业认定普遍以 CSSCI 或北大核心为准，不要搞混。

# %% [markdown]
# ## 二、根据实际情况选期刊级别
#
# 选刊的第一步不是看哪本期刊好，而是**搞清楚你的约束条件**。
#
# **按毕业要求反推（最理性的选法）：**
#
# ```
# 你的情况                  →  目标级别建议
# ──────────────────────────────────────────────────
# 毕业无论文硬要求          →  普刊 / EI 会议 保底即可
# 专硕要求 1 篇核心         →  北大核心 或 CSSCI 之一
# 学硕要求 SCI              →  Q3/Q4 先投，有时间冲 Q2
# 博士要求高水平            →  Q1/Q2，或学校指定顶刊列表
# 时间紧（距毕业 <6 个月）  →  OA 快审期刊 或 EI 会议
# ```
#
# **关于 OA 期刊（Open Access）：**
# - 作者支付版面费（APC），通常 $500–$3000
# - 优点：审稿周期短（部分 1-2 个月），发表后开放获取，引用量往往更高
# - 风险：存在掠夺性期刊（Predatory Journal），投之前务必查 **DOAJ** 白名单
#   或反向查 **Beall List**（黑名单）

# %% [markdown]
# ## 三、选具体期刊的方法
#
# **第一步：定方向候选池**
#
# 在 Google Scholar 或 WOS 里，搜你论文的核心关键词，看搜索结果里哪些期刊出现频率最高——这些就是你所在细分赛道的主流阵地。
#
# **第二步：逐本评估匹配度**
#
# 打开每本期刊的官网，重点看：
# - **Aims & Scope**：你的研究主题在不在它的覆盖范围内
# - **最近接受的文章**：题目和方法与你的研究像不像
# - **作者投稿指南（Author Guidelines）**：字数限制、参考文献格式等
#
# **第三步：查询期刊的"隐性信息"**
#
# 中国学者常用工具：[Letpub](https://www.letpub.com.cn/)
#
# 可查到：
# - 平均审稿周期（很多期刊 3-6 个月，部分快审 1-2 个月）
# - 版面费金额（OA 类）
# - 中国大陆作者发文比例（过高或过低都值得注意）
# - 其他作者的投稿反馈
#
# **被拒之后换期刊：**
#
# 被拒不等于文章差，可能只是和期刊调性不符。
# 分析拒稿原因 → 降一档或换方向 → 按新期刊格式调整后重投。
# 核心内容不需要改，只需要适配格式。

# %% [markdown]
# ## 四、投稿流程全图
#
# ```
# 准备阶段
# ├─ 按期刊 Author Guidelines 调整格式（字体/行距/图表/参考文献）
# ├─ 写 Cover Letter（必须，下面有模板）
# └─ 准备声明文件（版权转让、利益冲突等，期刊要求各异）
#
# 提交阶段
# └─ 在线投稿系统（常见：ScholarOne / Editorial Manager）
#    上传主稿件 + 补充材料 + Cover Letter
#
# 编辑初审（1-3 周）
# ├─ Desk Rejection：不符合期刊范围，直接拒 → 换刊
# └─ 送审：进入同行评审（Peer Review）→ 等 2-6 个月
#
# 收到审稿意见
# ├─ Accept（极少见，恭喜）
# ├─ Minor Revision（小修，1-4 周内返回）
# ├─ Major Revision（大修，1-3 个月内返回，有机会）
# └─ Reject（被拒，分析原因，考虑换刊）
#
# 返修阶段
# └─ 准备 Point-by-point Response + 修改稿件 → 提交
#
# 最终接受 → 清样校对 → 在线优先发表（Online First）→ 正式见刊
# ```

# %% [markdown]
# ## 五、Cover Letter 怎么写
#
# Cover Letter 是你写给主编的一封信，核心要素：
#
# ```
# Dear Prof. [Editor Name] / Dear Editor-in-Chief,
#
# We submit the manuscript "[Title]" for consideration in [Journal Name].
#
# [一段话说清楚：研究问题是什么、用了什么方法、主要发现是什么、
# 为什么这对该期刊的读者有价值]
#
# We confirm that:
# • The manuscript is original and has not been published elsewhere.
# • It is not currently under review at another journal.
# • All authors have read and approved the final version.
# • There are no conflicts of interest.
#
# We look forward to hearing from you.
#
# Sincerely,
# [姓名 / 单位 / 联系邮箱]
# ```
#
# **几个细节：**
# - 如果主编姓名可查到，直接写名字，不要用"Dear Editor"（显得更用心）
# - 那段核心描述控制在 3-5 句，不要把摘要直接粘进去
# - 如果期刊有特殊声明要求（如伦理审查），在这里一并说明

# %% [markdown]
# ## 六、审稿意见返修的逻辑
#
# 收到 Major Revision 是好事，说明主编认为这篇文章有潜力。
#
# **返修的总体原则：**
#
# 首先，**审稿人说的不一定都对**，但你必须每一条都认真回应。
# 不认同的地方，可以礼貌但清晰地解释你的立场，并给出证据支撑。
#
# **四种常见情况的处理思路：**
#
# | 意见类型 | 处理策略 |
# |---------|---------|
# | 要求补充某个分析/实验 | 认真做，补进去，说明在哪里 |
# | 认为某个解释不充分 | 扩写对应段落，加引用支撑 |
# | 指出方法问题（有道理） | 坦诚承认，提供补充分析或解释局限性 |
# | 审稿人明显误读 | 礼貌指出，解释原文意图，必要时小幅改写让表述更清晰 |
#
# **逐条回复模板结构：**
#
# ```
# Reviewer 1, Comment 1:
# [原文审稿意见]
#
# Response:
# Thank you for this insightful comment. [你的回应]
# We have revised the manuscript accordingly.
# On page X, paragraph Y, we added / changed...
# ```

# %% [markdown]
# ---
#
# ## 七、中文期刊体系：CSSCI · 北大核心 · 普刊
#
# 国内期刊认定体系与国际不同，主要由三个数据库划定档次：
#
# | 数据库 | 全称 | 主管机构 | 大致档次 |
# |--------|------|----------|----------|
# | **CSSCI** | 中文社会科学引文索引 | 南京大学 | 顶级（社科） |
# | **CSCD** | 中国科学引文数据库 | 中国科学院 | 顶级（理工） |
# | **北大核心** | 中文核心期刊要目总览 | 北京大学 | 中坚力量 |
# | **AMI综合评价** | 人文社科期刊综合评价数据库 | 中国社科院 | 人文社科补充 |
# | **普刊** | 正规出版、有 CN 刊号，不在上述数据库 | — | 入门门槛 |
#
# **CSSCI 扩展版（CSSCI-E）** 也被部分高校认可，介于核心与普刊之间，可作为发表起步选项。
#
# > 关键判断：投哪个档次，取决于你所在学校对毕业/晋升的要求，先查院系文件，再选刊。

# %% [markdown]
# ## 八、中文论文写作的结构差异
#
# 中文期刊的行文逻辑与 SCI 有明显差异，切换赛道时需要重新校准语感。
#
# ### 整体结构对比
#
# | 维度 | 英文 SCI/SSCI | 中文 CSSCI/北大核心 |
# |------|--------------|-------------------|
# | 摘要字数 | 150–250 词，高度结构化 | 200–400 字，允许更多背景铺垫 |
# | 引言目的 | 一句话点出研究缺口 | 先铺政策/现实背景，再引理论缺口 |
# | 文献综述 | 融入引言，不单独成节 | 通常独立一节，按主题分段梳理 |
# | 数据与方法 | 强调识别策略，简洁 | 详细描述数据来源、处理步骤 |
# | 结论 | 聚焦贡献与 implications | 加"政策启示"，强调实践价值 |
# | 语言风格 | 主动句、简洁 | 被动句多，行文较正式 |
#
# ### 引言怎么写（中文逻辑）
#
# 中文引言通常分四段走：
#
# ```
# 第一段：现实/政策背景
#   → 这件事在中国有多重要，最好引官方数据或政策文件
#
# 第二段：文献综述精简版
#   → 国内外已做了什么，还差在哪里（2–3 段即可，留更多到综述节）
#
# 第三段：本文的研究设计
#   → 用什么数据、什么方法、研究什么问题
#
# 第四段：贡献声明
#   → 三条贡献：① 话题贡献 ② 方法贡献 ③ 政策贡献
# ```
#
# ### 文献综述怎么组织（中文独立综述节）
#
# 中文综述不是流水账，而是有结构的论证：
#
# 1. **按子议题分组**：每个子议题单独一段，段首给出该组文献的共同结论
# 2. **批判性收尾**：每个子议题末尾指出"但上述研究忽略了……"
# 3. **综合性收尾段**：全节最后一段直接点出本文填补的空白
#
# ### 结论与政策建议
#
# 中文期刊结论节通常需要两部分：
# - **研究结论**（与摘要对应，重申主要发现）
# - **政策建议**（从研究结论推导，给政府/企业/监管部门的实操建议）
#
# 政策建议要"落地"——不能只写"政府应重视……"，而要写"建议监管部门在……场景下采用……机制"。

# %% [markdown]
# ## 九、CSSCI / 核心期刊投稿实务
#
# ### 选刊的中文逻辑
#
# CSSCI 期刊约 700 种，北大核心约 1000 种，不同话题对口的期刊差异很大。选刊步骤：
#
# **第一步：看你的研究领域**
# - 经济学：《经济研究》《管理世界》《经济学（季刊）》（顶刊）；《财贸经济》《世界经济》（中坚）
# - 金融学：《金融研究》《经济学报》《投资研究》
# - 管理学：《管理科学》《中国管理科学》《管理评论》
# - 社会学/政策：《社会学研究》《公共管理学报》《中国行政管理》
#
# **第二步：看发表周期**
# - 顶刊审稿 6–18 个月，毕业前赶稿优先投中间档
# - 北大核心一般 2–4 个月出结果
#
# **第三步：看匹配度**
# - 下载该刊最近 1 年的 10 篇论文，判断：话题类型、数据偏好、方法偏好、页数是否匹配
#
# ### 中文投稿流程
#
# ```
# 写作完成
#   │
#   ├─ 知网/万方查重（一般要求 < 15%，顶刊 < 10%）
#   │
#   ├─ 按期刊模板调格式（字体宋体/仿宋，页眉页脚，参考文献格式）
#   │
#   ├─ 在期刊官网或采编系统提交（大多数不收邮件投稿）
#   │
#   ├─ 等待编辑初审（1–4 周）
#   │   ├─ 退稿 → 分析原因，改投下一刊
#   │   └─ 外审 → 等待 1–3 个月
#   │
#   ├─ 收到审稿意见
#   │   ├─ 大修 → 逐条回应（参照 A04 模板）
#   │   └─ 退稿 → 改期刊，不要大改文章方向
#   │
#   └─ 录用 → 定稿 → 支付版面费（核心期刊多数收费）
# ```
#
# ### 版面费说明
#
# 中文核心期刊普遍收取版面费（正常学术惯例，不是骗局）：
# - CSSCI 核心：通常 3,000–8,000 元
# - 北大核心：通常 1,500–4,000 元
# - 普刊：500–2,000 元不等
#
# > ⚠️ 警惕假刊：只要在知网/万方可检索、有正规 CN 刊号，收版面费是正常现象；不在任何数据库、付款后消失的是骗局。
#
# ### 普刊的价值与定位
#
# 普刊不等于"水刊"，在以下情况有现实意义：
# - 本科毕业要求（部分院校只需普刊）
# - 作为第一次投稿练手，积累对评审流程的感知
# - 快速发表会议摘要或短文，为后续引用铺路
#
# 普刊写作要点：话题时效性强（政策热点）、数据易获取（上市公司/Wind）、方法不过于复杂（OLS+稳健性即可）。

# %% [markdown]
# ---
# > 📌 下一步 → [A04 SCI 小论文写作](./A04_SCI小论文写作全指南.ipynb)
